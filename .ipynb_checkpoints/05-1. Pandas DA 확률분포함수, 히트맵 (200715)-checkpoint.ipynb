# %% [markdown]
# # <b>■ Pandas를 이용한 ML 수업 복습</b>
#
#     목표 : kaggle 상위권 성적표
#
#     1장. Pandas 사용법
#         - Series
#         - DataFrame
#         - loc, iloc 이용해서 데이터 검색
#     2장. Pandas를 사용하여 데이터 불러오기
#         - csv, excel, json, html 불러오기
#         - 코로나 데이터를 불러와서 10가지 질문 답변
#     3장. 데이터 살펴보기
#         - 데이터프레임의 구조 보는 명령어
#         - 데이터프레임의 통계요약정보
#         - Pandas 데이터프레임 내장 그래프
#     4장. 데이터 시각화 하기
#         - matplotlib 패키지 사용해서 데이터 시각화
#         - seaborn 패키지 사용해서 데이터 시각화
#     5장. 데이터 전처리
#     6장. 데이터를 위한 데이터프레임의 여러가지 기능
#     7장. 파이썬을 이용한 머신러닝

# %% [markdown]
# ## <b>■ 7장. 파이썬을 이용한 머신러닝</b>
#     목표 : kaggle 상위 1% 진입
#
#     1단계. 데이터 수집 및 탐색
#     2단계. 데이터 살펴보기(시각화)(4장) + 데이터 전처리(5,6장)
#     3단계. 머신러닝 모델 생성하기
#     4단계. 머신러닝 모델 평가하기
#     5단계. 머신러닝 모델 성능 개선하기

# %% [markdown]
# ### <b>■ seaborn 패키지 사용해서 데이터 시각화</b>
#     1. 산포도 그래프 + 회귀직선
#     2. 히스토그램 그래프(+확률 밀도 그래프)
#     3. 상관관계 그래프(heatmap)
#     4. 산포도 그래프
#     5. 막대 그래프
#     6. 빈도 그래프
#     7. 박스 그래프
#     8. 바이올린 그래프(분산확인)

# %% [markdown]
# ### <b>■ 히스토그램 그래프(+확률 밀도 그래프)</b>
#     머신러닝 모델 학습 시키기전에 학습할 데이터에 대해서 특히 종속변수에 대해서 데이터의 분포를 확인할 필요가 있다.
#
#         학습데이터-----------------> 머신러닝 모델----------------> 예측, 분류
#         종속변수의 데이터가
#         정규성을 띄는지

# %% [markdown]
# #### 예제1. 타이타닉의 운임 데이터의 분포가 어떻게 되고 정규성을 띄는지 히스토그램 그래프로 확인하는 예제

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize']=(30,10)
plt.rcParams.update({'font.size':22})

tit = sns.load_dataset('titanic')
sns.set_style('darkgrid')
sns.distplot(tit['fare'])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize']=(30,10)
plt.rcParams.update({'font.size':22})

tit = sns.load_dataset('titanic')
sns.set_style('darkgrid')
# sns.distplot(tit['fare']) # 히스토그램 + 확률밀도
# sns.distplot(tit['fare'],hist=False) # 확률밀도 함수 그래프
sns.distplot(tit['fare'],kde=False) # 히스토그램 그래프
plt.show()

# %% [markdown]
# ### ※ 문제136. R 머신러닝 회귀분석 시 사용했던 미국민의 의료비 데이터를 파이썬으로 불러와서 종속변수인 의료비(expenses)가 정규성을 띄는지 히스토그램 그래프로 확인하시오(insurance.csv)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

ins = pd.read_csv('insurance.csv', header=0)
sns.distplot(ins['expenses'])
plt.show()

# %% [markdown]
# #### <b>※ 확률밀도함수 그래프 설명</b>
#     확률밀도함수란 확률 변수의 분포를 나타내는 함수이다.
#     확률변수는 크게 2가지
#         1. 이산확률변수 : 정수와 같이 명확한 값을 변수 값으로 함
#         2. 연속확률변수 : 변수 값이 정수처럼 명확하지 못함. 확률변수가 연속량으로 표기되어 가능한 변수 값의 개수를 셀 수 없는 변수
#
#
# $$f(x)={{1}\over {\sqrt{2 \pi \sigma^2}}}\exp ^{-{(x-m)^{2}}\over {2 \sigma ^2}}$$

# %% [markdown]
# ### ※ 문제137. 확률밀도함수 공식을 이용하지 않고 초등학생 10만 명의 키를 랜덤으로 생성해서 다음의 문제를 푸시오.
# ### 10만 명의 초등학생 중  무작위로 한 명을 추출했을 때 이 어린이의 키가 145~150 사이에 있을 확률은?
#     np.random.randn(100_000)*5 + 140

# %%
import numpy as np
height = np.random.randn(100_000)*5 + 140
cnt = 0
for i in height:
    if i>=145 and i<=150:
        cnt += 1
cnt/100000
# Out:
# 0.13496

# %% [markdown]
# ### ※ 문제138. 위의 초등학생 키 데이터로 확률밀도함수 그래프를 그리시오.
#     초등학생 키 140~160 사이의 키로 무작위로 생성하고 평균키를 150, 표준편차를 5로해서 확률밀도함수 그래프를 그리시오
#     패키지 scipy 이용

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

height = np.arange(140,160,0.001)
plt.plot(height, norm.pdf(height, 150, 5))
plt.show()

# %% [markdown]
# ### ※ 문제139. kaggle 타이타닉의 나이 데이터를 히스토그램 그래프로 시각화해서 나이의 분포를 확인하시오

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

tit = pd.read_csv('train.csv')
sns.distplot(tit['Age'],kde=False)

# %% [markdown]
# #### <b> 머신러닝 모델에 학습 데이터를 넣기 전 주의사항</b>
#     1. 결측치 처리
#     2. 이상치 처리(잡음(에러)이 있는지)
#
#     분류하는 인공지능을 만들 때 학습 데이터 안에 잡음(에러)를 처리하지 않아서 정확도가 20~30%
#
#     나이의 결측치를 처리하고 히스토그램 그래프를 그려서 분포 파악
#         1. 컬럼의 데이터의 평균값으로 치환
#         2. 컬럼의 데이터의 최빈값으로 치환
#         3. 컬럼의 데이터의 회귀 예상치로 치환

# %% [markdown]
# ### ※ 문제140. kaggle 타이타닉 나이 데이터의 결측치가 몇 개 있는지 확인하시오

# %%
sum(tit['Age'].isnull()), pd.isnull(tit['Age']).sum()
# Out:
# (177, 177)

# %% [markdown]
# ### ※ 문제141. kaggle 타이타닉 나이 데이터의 결측치를 나이 평균값으로 채워넣으시오

# %%
tit['Age'].mean() # 결측치(NaN) 제외한 값
# Out:
# 29.69911764705882

# %%
tit['Age'].fillna(int(tit['Age'].mean()), inplace=True)
sum(tit['Age'].isnull())
# Out:
# 0

# %% [markdown]
# ### ※ 문제142. 우리가 잘했는지 히스토그램 그래프로 확인하시오

# %%
sns.distplot(tit['Age'])

# %% [markdown]
# #### <b> 위의 나이 상태로 머신러닝 모델을 생성해보면 결과가 좋지 않다. 따라서 데이터를 꼭 시각화 해봐야한다.</b>

# %% [markdown]
# ### ※ 문제143. 이번에는 타이타닉 나이의 결측치를 평균값이 아니라 결측치의 바로 앞에 있는 값으로 치환해서 시각화를 하시오

# %%
import pandas as pd
import seaborn as sns

tit = pd.read_csv('train.csv')
tit['Age'].fillna(method='ffill', inplace=True)
# tit['Age'].mean(), sum(tit['Age'].isnull())

sns.distplot(tit['Age'])

# %% [markdown]
# #### <b> 머신러닝 모델에 학습을 시키기 전에 데이터 분포를 파악하기 위해서 히스토그램 그래프를 그리는 이유 -> 데이터의 정규성을 확인해야 머신러닝 모델이 잘 학습할 수 있는지 없는지 파악 가능</b>

# %% [markdown]
# ## <b>■ 히트맵(heatmap) 그래프</b>
#     색상으로 표현할 수 있는 다양한 정보를 일정한 이미지위에 열 분포 형태의 비주얼한 그래픽으로 출력하는 그래프
#
#     예: 웹사이트에 방문하는 방문자의 클릭을 열 분포 그래프로 표현
#         타이타닉의 나이와 class를 x축과 y축으로 두고 나이별로 어떤 클래스가 더 많은지 한 눈에 파악하고자 할 때
#
#     2차원 데이터를 계층적 클러스터링으로 시각화하는 방법

# %%
flights = sns.load_dataset('flights')
# flights.head()
df = flights.pivot('month','year','passengers')
df.head(12)
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(df, annot=True, fmt='d') # annot = True를 써서 각 셀에 숫자가 표시, fmt='d' 정수형태로 표시

# %%
sns.heatmap(df,cmap='YlGnBu', annot=True, fmt='d')

# %% [markdown]
#     Pandas의 히트맵 그래프 기능을 이용해서 그려보시오

# %%
df.style.background_gradient(cmap='summer')
# Out:
# <style  type="text/css" >
#     #T_379000b0_c648_11ea_9973_bc0ac2b8a8f2row0_col0 {
#             background-color:  #2e9666;
#             color:  #000000;
#         }    #T_379000b0_c648_11ea_9973_bc0ac2b8a8f2row0_col1 {
#             background-color:  #048266;
#             color:  #f1f1f1;
#         }    #T_379000b0_c648_11ea_9973_bc0ac2b8a8f2row0_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_379000b0_c648_11ea_9973_bc0ac2b8a8f2row0_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_379000b0_c648_11ea_9973_bc0ac2b8a8f2row0_col4 {
#             background-color:  #2c9666;
#             color:  #000000;
#         }    #T_379000b0_c648_11ea_9973_bc0ac2b8a8f2row0_col5 {
#             background-color:  #239166;
#             color:  #000000;
#         }    #T_379000b0_c648_11ea_9973_bc0ac2b8a8f2row0_col6 {
#             background-color:  #118866;
#             color:  #000000;
# ...

# %% [markdown]
# ### ※ 문제144. (점심시간 문제) seaborn의 타이타닉 데이터에서 성별과 class를 이용해서 히트맵 그래프를 그리시오

# %%
tit = sns.load_dataset('titanic')
# tit.head()
table = tit.pivot_table(index=['sex'],columns=['class'],aggfunc='size') # aggfunc='size' 데이터의 값의 크기를 기준으로 집계
table
sns.heatmap(table, annot=True, fmt='d')

# %%
table.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_565eca86_c649_11ea_a0c5_bc0ac2b8a8f2row0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_565eca86_c649_11ea_a0c5_bc0ac2b8a8f2row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_565eca86_c649_11ea_a0c5_bc0ac2b8a8f2row0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_565eca86_c649_11ea_a0c5_bc0ac2b8a8f2row1_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_565eca86_c649_11ea_a0c5_bc0ac2b8a8f2row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_565eca86_c649_11ea_a0c5_bc0ac2b8a8f2row1_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
# ...
