# %%
import numpy as np
from numpy.linalg import svd

A = np.array([[3, -1], [1, 3], [1, 1]])
U, S, VT = svd(A)

# %%
U
# Out:
# array([[-4.08248290e-01,  8.94427191e-01, -1.82574186e-01],
#        [-8.16496581e-01, -4.47213595e-01, -3.65148372e-01],
#        [-4.08248290e-01, -1.94289029e-16,  9.12870929e-01]])

# %%
S
# Out:
# array([3.46410162, 3.16227766])

# %%
np.diag(S,1)[:,1:]
# Out:
# array([[3.46410162, 0.        ],
#        [0.        , 3.16227766],
#        [0.        , 0.        ]])

# %%
VT
# Out:
# array([[-0.70710678, -0.70710678],
#        [ 0.70710678, -0.70710678]])

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import numpy as np
import scipy as sp
import pandas as pd
import statsmodels.api as sm
import sklearn as sk

plt.rcParams["figure.figsize"] = (12,12)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams.update({'font.size': 22})

w = np.array([1, 2])
x1 = np.array([3, 1])
x2 = np.array([-1, 3])
plt.annotate('', xy=w, xytext=(0, 0), arrowprops=dict(facecolor='black'))
plt.annotate('', xy=x1, xytext=(0, 0), arrowprops=dict(facecolor='green'))
plt.annotate('', xy=x2, xytext=(0, 0), arrowprops=dict(facecolor='green'))
plt.plot(0, 0, 'kP', ms=10)
plt.plot(w[0], w[1], 'ro', ms=10)
plt.plot(x1[0], x1[1], 'ro', ms=10)
plt.plot(x2[0], x2[1], 'ro', ms=10)
plt.plot([-3, 5], [4, 0], 'r-', lw=5)

plt.text(-0.2, 1.5, "벡터 $w$")
plt.text(1.55, 0.25, "$x_1$")
plt.text(-0.9, 1.40, "$x_2$")
plt.text(1.8, 1.8, "$x_1 - w$")
plt.text(-0.2, 2.8, "$x_2 - w$")
plt.text(3.6, 0.8, "직선 $x$")
plt.xticks(np.arange(-2, 5))
plt.yticks(np.arange(-1, 5))
plt.xlim(-2, 5)
plt.ylim(-0.6, 3.6)
plt.show()
