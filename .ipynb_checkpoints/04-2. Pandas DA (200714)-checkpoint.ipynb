# %% [markdown]
# # <b> ■ 4장. 시각화 도구</b>
#     *데이터 분석 단계
#         1. 데이터 수집 및 탐색
#         2. 데이터 살펴보기 -> 시각화 4장
#         3. ML 모델 훈련
#         4. ML 모델 평가
#         5. ML 모델 성능 개선
#
#     matplotlib를 이용해서 시각화
#         파이썬의 표준 시각화 도구로 불릴만큼 가장 범용적으로 많이 사용하는 시각화 패키지

# %% [markdown]
#     order : 서울에서 경기도 지역으로 이동한 인구수를 연도별로 각각 어떻게 되는지 라인그래프로 시각화

# %% [markdown]
# ### ※ 문제106. '시도별 전출입 인구수.xlsx' 파일을 불러와서 Pandas 데이터프레임으로 만드시오

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(30,10)
plt.rcParams.update({'font.size':22})
census = pd.read_excel('prac/시도별 전출입 인구수.xlsx',header=0)
census
# Out:
#      전출지별     전입지별      1970      1971      1972      1973      1974  \
# 0    전출지별     전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1      전국       전국   4046536   4210164   3687938   4860418   5297969
# 2     NaN    서울특별시   1742813   1671705   1349333   1831858   2050392
# 3     NaN    부산광역시    448577    389797    362202    482061    680984
# 4     NaN    대구광역시         -         -         -         -         -
# ..    ...      ...       ...       ...       ...       ...       ...
# 320   NaN     전라북도       139       202       141       210       219
# 321   NaN     전라남도       631       965       857       952      1133
# 322   NaN     경상북도       374       619       468       576       625
# 323   NaN     경상남도       474       479       440       571      1208
# 324   NaN  제주특별자치도      9290     12427     12210     16158     19580
#
#          1975      1976      1977  ...      2008      2009      2010  \
# ...

# %% [markdown]
# <b> ※ 보통 excel 데이터는 결측치 데이터가 많은데 데이터 내에 전출지별 column에 누락 데이터(NaN)이 다수 존재<br><br>
#    　누락데이터는 excel 파일에서 병합된 셀을 데이터프레임으로 변환할 때 적절한 값을 찾지 못해서 발생</b>

# %% [markdown]
# ### ※ 문제107. 누락데이터(NaN)의 앞 행을 데이터로 채우시오(excel 양식의 병합된 부분)

# %%
df = census.fillna(method='ffill')
df
# Out:
#         전출지별     전입지별      1970      1971      1972      1973      1974  \
# 0       전출지별     전입지별  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)  이동자수 (명)
# 1         전국       전국   4046536   4210164   3687938   4860418   5297969
# 2         전국    서울특별시   1742813   1671705   1349333   1831858   2050392
# 3         전국    부산광역시    448577    389797    362202    482061    680984
# 4         전국    대구광역시         -         -         -         -         -
# ..       ...      ...       ...       ...       ...       ...       ...
# 320  제주특별자치도     전라북도       139       202       141       210       219
# 321  제주특별자치도     전라남도       631       965       857       952      1133
# 322  제주특별자치도     경상북도       374       619       468       576       625
# 323  제주특별자치도     경상남도       474       479       440       571      1208
# 324  제주특별자치도  제주특별자치도      9290     12427     12210     16158     19580
#
#          1975      1976      1977  ...      2008      2009      2010  \
# ...

# %% [markdown]
# ### ※ 문제108. df 데이터프레임에서 column명을 추출하시오

# %%
df.columns
# Out:
# Index(['전출지별', '전입지별', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017'],
#       dtype='object')

# %% [markdown]
# ### ※ 문제109. excel에서 전출지별이 서울특별시인 전출지별과 전입지별을 출력하시오
#     문법
#         df[['col1','col2']][row조건]

# %%
df[['전출지별','전입지별']][df['전출지별']=='서울특별시']
# Out:
#      전출지별     전입지별
# 19  서울특별시       전국
# 20  서울특별시    서울특별시
# 21  서울특별시    부산광역시
# 22  서울특별시    대구광역시
# 23  서울특별시    인천광역시
# 24  서울특별시    광주광역시
# 25  서울특별시    대전광역시
# 26  서울특별시    울산광역시
# 27  서울특별시  세종특별자치시
# 28  서울특별시      경기도
# 29  서울특별시      강원도
# 30  서울특별시     충청북도
# 31  서울특별시     충청남도
# 32  서울특별시     전라북도
# 33  서울특별시     전라남도
# 34  서울특별시     경상북도
# 35  서울특별시     경상남도
# 36  서울특별시  제주특별자치도

# %% [markdown]
# ### ※ 문제110. 위의 결과에서 전출지별이 서울특별시이고 전입지별이 서울특별시인 행은 출력되지 않게 하시오

# %%
df[['전출지별','전입지별']][(df['전출지별']=='서울특별시')&(df['전입지별']!='서울특별시')]
# Out:
#      전출지별     전입지별
# 19  서울특별시       전국
# 21  서울특별시    부산광역시
# 22  서울특별시    대구광역시
# 23  서울특별시    인천광역시
# 24  서울특별시    광주광역시
# 25  서울특별시    대전광역시
# 26  서울특별시    울산광역시
# 27  서울특별시  세종특별자치시
# 28  서울특별시      경기도
# 29  서울특별시      강원도
# 30  서울특별시     충청북도
# 31  서울특별시     충청남도
# 32  서울특별시     전라북도
# 33  서울특별시     전라남도
# 34  서울특별시     경상북도
# 35  서울특별시     경상남도
# 36  서울특별시  제주특별자치도

# %% [markdown]
# ### ※ 문제111. 위의 조건에 맞는 모든 열들을 다 출력하시오

# %%
mask = df[['전출지별','전입지별']][(df['전출지별']=='서울특별시')&(df['전입지별']!='서울특별시')]
df_seoul = df[:][(df['전출지별']=='서울특별시')&(df['전입지별']!='서울특별시')]
df_seoul
# Out:
#      전출지별     전입지별     1970     1971     1972     1973     1974     1975  \
# 19  서울특별시       전국  1448985  1419016  1210559  1647268  1819660  2937093
# 21  서울특별시    부산광역시    11568    11130    11768    16307    22220    27515
# 22  서울특별시    대구광역시        -        -        -        -        -        -
# 23  서울특별시    인천광역시        -        -        -        -        -        -
# 24  서울특별시    광주광역시        -        -        -        -        -        -
# 25  서울특별시    대전광역시        -        -        -        -        -        -
# 26  서울특별시    울산광역시        -        -        -        -        -        -
# 27  서울특별시  세종특별자치시        -        -        -        -        -        -
# 28  서울특별시      경기도   130149   150313    93333   143234   149045   253705
# 29  서울특별시      강원도     9352    12885    13561    16481    15479    27837
# 30  서울특별시     충청북도     6700     9457    10853    12617    11786    21073
# 31  서울특별시     충청남도    15954    18943    23406    27139    25509    51205
# ...

# %% [markdown]
# ### ※ 문제112. 위의 df 데이터프레임에서 전출지별 column을 삭제하시오
#     문법
#         df.drop(column명, axis=1)

# %%
df_seoul.drop('전출지별',axis=1,inplace=True)
df_seoul
# Out:
#        전입지별     1970     1971     1972     1973     1974     1975     1976  \
# 19       전국  1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 21    부산광역시    11568    11130    11768    16307    22220    27515    23732
# 22    대구광역시        -        -        -        -        -        -        -
# 23    인천광역시        -        -        -        -        -        -        -
# 24    광주광역시        -        -        -        -        -        -        -
# 25    대전광역시        -        -        -        -        -        -        -
# 26    울산광역시        -        -        -        -        -        -        -
# 27  세종특별자치시        -        -        -        -        -        -        -
# 28      경기도   130149   150313    93333   143234   149045   253705   202276
# 29      강원도     9352    12885    13561    16481    15479    27837    25927
# 30     충청북도     6700     9457    10853    12617    11786    21073    18029
# ...

# %% [markdown]
# ### ※ 문제113. 위의 df_seoul 데이터프레임에서 column명 전입지별을 전입지로 변경하시오
#     문법
#         df_seoul.rename({'기존컬럼':'변경컬럼명'},axis=1,inplace=True)

# %%
df_seoul.rename({'전입지별':'전입지'},axis=1,inplace=True)
df_seoul
# Out:
#         전입지     1970     1971     1972     1973     1974     1975     1976  \
# 19       전국  1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 21    부산광역시    11568    11130    11768    16307    22220    27515    23732
# 22    대구광역시        -        -        -        -        -        -        -
# 23    인천광역시        -        -        -        -        -        -        -
# 24    광주광역시        -        -        -        -        -        -        -
# 25    대전광역시        -        -        -        -        -        -        -
# 26    울산광역시        -        -        -        -        -        -        -
# 27  세종특별자치시        -        -        -        -        -        -        -
# 28      경기도   130149   150313    93333   143234   149045   253705   202276
# 29      강원도     9352    12885    13561    16481    15479    27837    25927
# 30     충청북도     6700     9457    10853    12617    11786    21073    18029
# ...

# %% [markdown]
# ### ※ 문제114. 전입지 column을 행 index로 지정하시오
#     문법
#         df.set_index('col',inplace=True)

# %%
df_seoul.set_index('전입지',inplace=True)
df_seoul
# Out:
#             1970     1971     1972     1973     1974     1975     1976  \
# 전입지
# 전국       1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 부산광역시      11568    11130    11768    16307    22220    27515    23732
# 대구광역시          -        -        -        -        -        -        -
# 인천광역시          -        -        -        -        -        -        -
# 광주광역시          -        -        -        -        -        -        -
# 대전광역시          -        -        -        -        -        -        -
# 울산광역시          -        -        -        -        -        -        -
# 세종특별자치시        -        -        -        -        -        -        -
# 경기도       130149   150313    93333   143234   149045   253705   202276
# 강원도         9352    12885    13561    16481    15479    27837    25927
# 충청북도        6700     9457    10853    12617    11786    21073    18029
# 충청남도       15954    18943    23406    27139    25509    51205    41447
# ...

# %% [markdown]
# ### ※ 문제115. 위의 결과에서 경기도 데이터만 가져오시오
#     문법
#         df.loc['행 index 이름']

# %%
rs = df_seoul.loc['경기도']
rs
# Out:
# 1970    130149
# 1971    150313
# 1972     93333
# 1973    143234
# 1974    149045
# 1975    253705
# 1976    202276
# 1977    207722
# 1978    237684
# 1979    278411
# 1980    297539
# 1981    252073
# 1982    320174
# 1983    400875
# 1984    352238
# 1985    390265
# 1986    412535
# 1987    405220
# 1988    415174
# 1989    412933
# 1990    473889
# 1991    384714
# 1992    428344
# 1993    502584
# 1994    542204
# 1995    599411
# 1996    520566
# 1997    495454
# 1998    407050
# 1999    471841
# 2000    435573
# 2001    499575
# 2002    516765
# 2003    457656
# 2004    400206
# 2005    414621
# 2006    449632
# 2007    431637
# 2008    412408
# 2009    398282
# 2010    410735
# 2011    373771
# 2012    354135
# 2013    340801
# 2014    332785
# 2015    359337
# 2016    370760
# 2017    342433
# Name: 경기도, dtype: object

# %% [markdown]
# ### ※ 문제116. 위의 데이터를 가지고 라인 그래프를 그리시오

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(30,10)
plt.rcParams.update({'font.size':12})
pd.options.plotting.backend = "matplotlib"

census = pd.read_excel('prac/시도별 전출입 인구수.xlsx',header=0)
df = census.fillna(method='ffill')
df_seoul = df[:][(df['전출지별']=='서울특별시')&(df['전입지별']!='서울특별시')]
df_seoul.drop('전출지별',axis=1,inplace=True)
df_seoul.rename({'전입지별':'전입지'},axis=1,inplace=True)
df_seoul.set_index('전입지',inplace=True)
rs = df_seoul.loc['경기도']
plt.plot(rs.index, rs.values)

# %% [markdown]
# ### ※ 문제117. $x$축 눈금의 라벨을 90도 회전 시키시오

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(30,10)
plt.rcParams.update({'font.size':12})
pd.options.plotting.backend = "matplotlib"

census = pd.read_excel('prac/시도별 전출입 인구수.xlsx',header=0)
df = census.fillna(method='ffill')
df_seoul = df[:][(df['전출지별']=='서울특별시')&(df['전입지별']!='서울특별시')]
df_seoul.drop('전출지별',axis=1,inplace=True)
df_seoul.rename({'전입지별':'전입지'},axis=1,inplace=True)
df_seoul.set_index('전입지',inplace=True)
rs = df_seoul.loc['경기도']
plt.xticks(size=20,rotation=45)
plt.plot(rs.index, rs.values)

# %%
# 유리 코드
df_seoul = df[ : ][ ( df['전출지별']=='서울특별시') &  ( df['전입지별'] != '서울특별시')  ] 
df_seoul.drop( '전출지별', axis=1, inplace=True)

df_seoul.rename( {'전입지별' : '전입지' }, axis=1, inplace=True)
df_seoul.set_index('전입지', inplace=True)

result= df_seoul.loc['경기도']

plt.plot( result.index, result.values)
plt.xticks( size=30,  rotation=45) 

result= df_seoul.loc[['경기도']]
result1 = result.T 

result1.plot()

# %% [markdown]
# ### ※ 문제118. 제목 추가

# %%
# matplotlib 한글 폰트 오류 문제 해결

from matplotlib import font_manager, rc

font_path = "prac/malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(30,10)
plt.rcParams.update({'font.size':20})
pd.options.plotting.backend = "matplotlib"

census = pd.read_excel('prac/시도별 전출입 인구수.xlsx',header=0)
df = census.fillna(method='ffill')
df_seoul = df[:][(df['전출지별']=='서울특별시')&(df['전입지별']!='서울특별시')]
df_seoul.drop('전출지별',axis=1,inplace=True)
df_seoul.rename({'전입지별':'전입지'},axis=1,inplace=True)
df_seoul.set_index('전입지',inplace=True)
rs = df_seoul.loc['경기도']

# 제목 추가
plt.title( '서울 -> 경기 인구 이동',)

# 축이름 추가
plt.xlabel('기간')
plt.ylabel('이동 인구수')

plt.style.use('Solarize_Light2')
plt.xticks(size=25,rotation=45)
plt.plot(rs.index, rs.values)
plt.show()

# %% [markdown]
# ### ※ 문제119. ggplot 스타일로 변경하시오

# %%
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib import font_manager, rc

font_path = "prac/malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

plt.rcParams['figure.figsize']=(30,10)
plt.rcParams.update({'font.size':20})
pd.options.plotting.backend = "matplotlib"

census = pd.read_excel('prac/시도별 전출입 인구수.xlsx',header=0)
df = census.fillna(method='ffill')
df_seoul = df[:][(df['전출지별']=='서울특별시')&(df['전입지별']!='서울특별시')]
df_seoul.drop('전출지별',axis=1,inplace=True)
df_seoul.rename({'전입지별':'전입지'},axis=1,inplace=True)
df_seoul.set_index('전입지',inplace=True)
rs = df_seoul.loc['경기도']

# 제목 추가
plt.title( '서울 -> 경기 인구 이동',)

# 축이름 추가
plt.xlabel('기간')
plt.ylabel('이동 인구수')

plt.style.use('ggplot')
plt.xticks(size=25,rotation=45)
plt.plot(rs.index, rs.values)

plt.show()

# %% [markdown]
# ### ※ 문제120. 그래프로 출력될 수 있는 스타일을 출력하시오

# %%
import matplotlib.pyplot as plt
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# ### ※ 문제121. annotation을 추가하시오

# %%
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib import font_manager, rc

font_path = "prac/malgun.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

plt.rcParams['figure.figsize']=(30,10)
plt.rcParams.update({'font.size':20})
pd.options.plotting.backend = "matplotlib"

census = pd.read_excel('prac/시도별 전출입 인구수.xlsx',header=0)
df = census.fillna(method='ffill')
df_seoul = df[:][(df['전출지별']=='서울특별시')&(df['전입지별']!='서울특별시')]
df_seoul.drop('전출지별',axis=1,inplace=True)
df_seoul.rename({'전입지별':'전입지'},axis=1,inplace=True)
df_seoul.set_index('전입지',inplace=True)
rs = df_seoul.loc['경기도']

# 제목 추가
plt.title( '서울 -> 경기 인구 이동',)

# 축이름 추가
plt.xlabel('기간')
plt.ylabel('이동 인구수')

plt.style.use('ggplot')
plt.xticks(size=25,rotation=45)
plt.yticks(size=25)
plt.plot(rs.index, rs.values)

# 주석 표시 - 화살표
plt.annotate('',
             xy=(20, 520000),       #화살표의 머리 부분(끝점)
             xytext=(2, 290000),    #화살표의 꼬리 부분(시작점)
             xycoords='data',       #좌표체계
             arrowprops=dict(arrowstyle='->', color='skyblue', lw=5), #화살표 서식
             )

plt.annotate('',
             xy=(47, 450000),       #화살표의 머리 부분(끝점)
             xytext=(30, 580000),   #화살표의 꼬리 부분(시작점)
             xycoords='data',       #좌표체계
             arrowprops=dict(arrowstyle='->', color='olive', lw=5),  #화살표 서식
             )

# 주석 표시 - 텍스트
plt.annotate('인구이동 증가(1970-1995)',  #텍스트 입력
             xy=(10, 390000),            #텍스트 위치 기준점
             rotation=19,                #텍스트 회전각도
             va='baseline',              #텍스트 상하 정렬
             ha='center',                #텍스트 좌우 정렬
             fontsize=25,                #텍스트 크기
             )

plt.annotate('인구이동 감소(1995-2017)',  #텍스트 입력
             xy=(40, 490000),            #텍스트 위치 기준점
             rotation=-11,               #텍스트 회전각도
             va='baseline',              #텍스트 상하 정렬
             ha='center',                #텍스트 좌우 정렬
             fontsize=25,                #텍스트 크기
            color="red"
             )

plt.show()

# %% [markdown]
# ### ※ 문제122. 위의 그래프에 제목의 색깔을 변경하고 글씨를 더 굵게 출력하시오

# %%
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib import font_manager, rc

font_path = "prac/malgun.ttf"   
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

plt.rcParams['figure.figsize']=(30,10)
plt.rcParams.update({'font.size':20})
pd.options.plotting.backend = "matplotlib"

census = pd.read_excel('prac/시도별 전출입 인구수.xlsx',header=0)
df = census.fillna(method='ffill')
df_seoul = df[:][(df['전출지별']=='서울특별시')&(df['전입지별']!='서울특별시')]
df_seoul.drop('전출지별',axis=1,inplace=True)
df_seoul.rename({'전입지별':'전입지'},axis=1,inplace=True)
df_seoul.set_index('전입지',inplace=True)
rs = df_seoul.loc['경기도']

# 제목 추가
plt.title( '서울 -> 경기 인구 이동',color='brown',weight='bold')

# 축이름 추가
plt.xlabel('기간')
plt.ylabel('이동 인구수')

plt.style.use('ggplot')
plt.xticks(size=25,rotation=45)
plt.yticks(size=25)
plt.plot(rs.index, rs.values)

# 주석 표시 - 화살표
plt.annotate('',
             xy=(20, 520000),       #화살표의 머리 부분(끝점)
             xytext=(2, 290000),    #화살표의 꼬리 부분(시작점)
             xycoords='data',       #좌표체계
             arrowprops=dict(arrowstyle='->', color='skyblue', lw=5), #화살표 서식
             )

plt.annotate('',
             xy=(47, 450000),       #화살표의 머리 부분(끝점)
             xytext=(30, 580000),   #화살표의 꼬리 부분(시작점)
             xycoords='data',       #좌표체계
             arrowprops=dict(arrowstyle='->', color='olive', lw=5),  #화살표 서식
             )

# 주석 표시 - 텍스트
plt.annotate('인구이동 증가(1970-1995)',  #텍스트 입력
             xy=(10, 390000),            #텍스트 위치 기준점
             rotation=19,                #텍스트 회전각도
             va='baseline',              #텍스트 상하 정렬
             ha='center',                #텍스트 좌우 정렬
             fontsize=25,                #텍스트 크기
             )

plt.annotate('인구이동 감소(1995-2017)',  #텍스트 입력
             xy=(40, 490000),            #텍스트 위치 기준점
             rotation=-11,               #텍스트 회전각도
             va='baseline',              #텍스트 상하 정렬
             ha='center',                #텍스트 좌우 정렬
             fontsize=25,                #텍스트 크기
            color="red"
             )

plt.show()

# %% [markdown]
# ## <b>■ ggplot 스타일로 막대 그래프 구현하기</b>
#     문법
#         df.plot(kind='bar',figsize=(20,10),width=0.7,
#                 color=['orange','green','skyblue','blue'])

# %%
df_seoul
# Out:
#             1970     1971     1972     1973     1974     1975     1976  \
# 전입지
# 전국       1448985  1419016  1210559  1647268  1819660  2937093  2495620
# 부산광역시      11568    11130    11768    16307    22220    27515    23732
# 대구광역시          -        -        -        -        -        -        -
# 인천광역시          -        -        -        -        -        -        -
# 광주광역시          -        -        -        -        -        -        -
# 대전광역시          -        -        -        -        -        -        -
# 울산광역시          -        -        -        -        -        -        -
# 세종특별자치시        -        -        -        -        -        -        -
# 경기도       130149   150313    93333   143234   149045   253705   202276
# 강원도         9352    12885    13561    16481    15479    27837    25927
# 충청북도        6700     9457    10853    12617    11786    21073    18029
# 충청남도       15954    18943    23406    27139    25509    51205    41447
# ...

# %% [markdown]
# ### ※ 문제123. df_seoul 데이터프레임에서 충청남도, 경상북도, 강원도, 전라남도 데이터만 검색하시오

# %%
df_seoul.loc[['충청남도','경상북도','강원도','전라남도']]
# Out:
#        1970   1971   1972   1973   1974   1975   1976   1977   1978   1979  \
# 전입지
# 충청남도  15954  18943  23406  27139  25509  51205  41447  43993  48091  45388
# 경상북도  11868  16459  22073  27531  26902  46177  40376  41155  42940  43565
# 강원도    9352  12885  13561  16481  15479  27837  25927  25415  26700  27599
# 전라남도  10513  16755  20157  22160  21314  46610  46251  43430  44624  47934
#
#       ...   2008   2009   2010   2011   2012   2013   2014   2015   2016  \
# 전입지   ...
# 충청남도  ...  27458  24889  24522  24723  22269  21486  21473  22299  21741
# 경상북도  ...  15425  16569  16042  15818  15191  14420  14456  15113  14236
# 강원도   ...  23668  23331  22736  23624  22332  20601  21173  22659  21590
# 전라남도  ...  16601  17468  16429  15974  14765  14187  14591  14598  13065
#
#        2017
# 전입지
# 충청남도  21020
# 경상북도  12464
# 강원도   21016
# 전라남도  12426
#
# [4 rows x 48 columns]

# %% [markdown]
# ### ※ 문제124. 위의 결과가 1970년도부터 다 나오게 하지 말고 2010~2017년도까지만 검색하시오

# %%
col_years=list(map(str, range(2010,2018)))
df_seoul.loc[['충청남도','경상북도','강원도','전라남도'],col_years]
# Out:
#        2010   2011   2012   2013   2014   2015   2016   2017
# 전입지
# 충청남도  24522  24723  22269  21486  21473  22299  21741  21020
# 경상북도  16042  15818  15191  14420  14456  15113  14236  12464
# 강원도   22736  23624  22332  20601  21173  22659  21590  21016
# 전라남도  16429  15974  14765  14187  14591  14598  13065  12426

# %%
df_seoul.loc[['충청남도','경상북도','강원도','전라남도'],'2010':'2017']
# Out:
#        2010   2011   2012   2013   2014   2015   2016   2017
# 전입지
# 충청남도  24522  24723  22269  21486  21473  22299  21741  21020
# 경상북도  16042  15818  15191  14420  14456  15113  14236  12464
# 강원도   22736  23624  22332  20601  21173  22659  21590  21016
# 전라남도  16429  15974  14765  14187  14591  14598  13065  12426

# %% [markdown]
# ### ※ 문제125. 위의 결과를 전치시켜서 df_4 변수에 담으시오

# %%
df_4 = df_seoul.loc[['충청남도','경상북도','강원도','전라남도'],'2010':'2017'].T
df_4
# Out:
# 전입지    충청남도   경상북도    강원도   전라남도
# 2010  24522  16042  22736  16429
# 2011  24723  15818  23624  15974
# 2012  22269  15191  22332  14765
# 2013  21486  14420  20601  14187
# 2014  21473  14456  21173  14591
# 2015  22299  15113  22659  14598
# 2016  21741  14236  21590  13065
# 2017  21020  12464  21016  12426

# %% [markdown]
# ### ※ 문제126. 위의 결과를 막대 그래프로 그리시오

# %%
df_4.plot.bar(width=0.7, color=['orange','green','skyblue','blue'])

# %% [markdown]
# ### ※ 문제127. ggplot 스타일로 출력하시오

# %%
font_path = "prac/malgun.ttf"   
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

plt.rcParams['figure.figsize']=(30,10)
plt.rcParams.update({'font.size':20})
plt.style.use('dark_background')
df_4.plot.bar(width=0.7, color=['orange','green','skyblue','blue'])

# %% [markdown]
# ### ※ 문제128. 업종별 창업건수를 막대 그래프를 그리기 위한 데이터프레임으로 만드시오

# %%
import pandas as pd
df5 = pd.read_csv('창업건수.csv', encoding='cp949')
df5
# Out:
#    year  hairshop  restaurant  sushi  chicken  cafe  korean_food  beer
# 0  2005      2196        1034    540      530   454         5994   635
# 1  2006      2028         950    577      525   483         5504   591
# 2  2007      1802        1036    620      507   575         6148   544
# 3  2008      1691        1127    561      543   772         6036   525
# 4  2009      1826        1086    645      711   845         6577   627
# 5  2010      1798        1105    669      865  1291         6689   553
# 6  2011      1688        1199    736      837  1671         6900   638
# 7  2012      1767        1183    753      986  1847         7082   687
# 8  2013      1965        1432    839      954  2287         7708   769
# 9  2014      1980        1870   1095     1193  3053         9772  1272

# %% [markdown]
# ### ※ 문제129. 위의 결과에서 연도, 커피음료, 치킨집, 한식음식점, 일식집만 가져오시오

# %%
df6 = df5[['year','cafe','chicken','korean_food','sushi']]
df6
# Out:
#    year  cafe  chicken  korean_food  sushi
# 0  2005   454      530         5994    540
# 1  2006   483      525         5504    577
# 2  2007   575      507         6148    620
# 3  2008   772      543         6036    561
# 4  2009   845      711         6577    645
# 5  2010  1291      865         6689    669
# 6  2011  1671      837         6900    736
# 7  2012  1847      986         7082    753
# 8  2013  2287      954         7708    839
# 9  2014  3053     1193         9772   1095

# %% [markdown]
# ### ※ 문제130. 위의 결과에서 연도 column을 행 index로 지정하시오

# %%
df6.set_index('year',inplace=True)
df6
# Out:
#       cafe  chicken  korean_food  sushi
# year
# 2005   454      530         5994    540
# 2006   483      525         5504    577
# 2007   575      507         6148    620
# 2008   772      543         6036    561
# 2009   845      711         6577    645
# 2010  1291      865         6689    669
# 2011  1671      837         6900    736
# 2012  1847      986         7082    753
# 2013  2287      954         7708    839
# 2014  3053     1193         9772   1095

# %% [markdown]
# ### ※ 문제131. 위의 데이터프레임으로 막대그래프를 그리시오

# %%
font_path = "prac/malgun.ttf"   
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

plt.rcParams['figure.figsize']=(30,10)
plt.rcParams.update({'font.size':20})
# plt.style.use('default')
df6.plot.bar(width=0.7, color=['orange','green','skyblue','blue'])

# %% [markdown]
# ### ※ 문제132. 위의 그래프에 제목을 붙이시오(제목이름: 연도별 창업건수)

# %%
plt.title('연도별 창업건수',size=30)
df6.plot.bar(width=0.7, color=['orange','green','skyblue','blue'])

# %% [markdown]
# ## <b>■ seaborn 라이브러리로 산포도 그래프 그리기</b>
#     seaborn은 matplotlib의 기능과 스타일을 확장한 파이썬 시각화 도구의 고급버전이다.

# %% [markdown]
# ### ※ 문제133. seaborn에 내장된 타이타닉 데이터를 가져오시오

# %%
import seaborn as sns
tit = sns.load_dataset('titanic')
tit.head()
tit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %% [markdown]
# ### ※ 문제134. 타이타닉 데이터에서 나이가 증가할 수록 운임(fare)가 증가하는지 산포도 그래프로 확인하시오

# %%
import seaborn as sns

tit = sns.load_dataset('titanic')
sns.set_style('darkgrid')

sns.regplot(x='age',y='fare',data=tit, fit_reg=True)
plt.show()

# %% [markdown]
# ### ※ 문제135. (오늘의 마지막 문제) 오전에 만든 코로나 이동성 데이터를 가지고 회귀직선을 생성하는데 $x$축을 driving으로 하고 $y$축을 확진자 수로 시각화 하시오 (정규화 된 데이터를 사용)

# %%
from sklearn import preprocessing
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (30,10)
plt.rcParams.update({'font.size': 22})
import pandas as pd

from matplotlib import font_manager, rc
font_path = "prac/malgun.ttf"   
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

korea_move = pd.read_csv("korea_move2.csv", header = None)
km = korea_move.T
km = km[6:]
km.columns = ['date', 'driving', 'walking']

url = "sample2.html"
url2 = pd.read_html(url)
dcnt = pd.DataFrame(url2[5][2].str.split('+'))[2].str[1].str.split(')').str[0]

d = url2[5][1]
r = pd.DataFrame({'date':d, 'cnt':dcnt})[2:-2]

#r.date = r.date.map(lambda x:x[:-1].replace('월 ', '-')).map(lambda x:'2020-0' + x).map(lambda x:x[0:8] + '0' + x[8] if x[-2] == '-' else x)
r.date = r.date.map(lambda x:'2020-0' + x[x.index('월') - 1] + '-' + x[x.index('월') + 2:x.index('일')].rjust(2, '0'))
result = pd.merge(km, r, on = 'date')

import re
for k, i in enumerate(result['cnt']):
    result['cnt'][k] = re.sub('[^0-9]','',i)
result['cnt']=result['cnt'].astype(int)
result[['driving','walking']] = result[['driving','walking']].astype(float)

date = result.date
X=result[['driving','walking','cnt']]
X=preprocessing.StandardScaler().fit(X).transform(X)
df = pd.DataFrame(X)
rs = pd.concat([date,df],axis=1)
rs.columns = ['date','driving','walking','cnt']

import seaborn as sns

sns.set_style('darkgrid')

sns.regplot(x='driving',y='cnt',data=result, fit_reg=True)
plt.show()
